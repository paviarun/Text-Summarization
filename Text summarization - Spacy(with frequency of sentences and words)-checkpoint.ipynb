# %%
# Load Pkgs
import spacy

# %%
# Text Preprocessing Pkg
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation

# %%
# Build a List of Stopwords
stopwords = list(STOP_WORDS)

# %%
stopwords
# Out:
# ['we',
#  'the',
#  'except',
#  'ours',
#  'thereby',
#  'not',
#  'also',
#  'much',
#  'nobody',
#  'ten',
#  'forty',
#  'was',
#  'upon',
#  'become',
#  'had',
#  'me',
#  'myself',
#  'towards',
#  'part',
#  'own',
#  'side',
#  'hundred',
#  'this',
#  'becomes',
#  'used',
#  'seeming',
#  'several',
#  'whither',
#  'hereupon',
#  'many',
#  'go',
#  'cannot',
#  "'s",
#  'no',
#  'those',
#  'just',
#  'nine',
#  'done',
#  'otherwise',
#  'yourselves',
#  'elsewhere',
#  'out',
#  'how',
#  'none',
#  'noone',
#  'hereafter',
#  'above',
#  'does',
#  'two',
#  'within',
#  'whatever',
#  'under',
#  'n‘t',
#  'really',
#  'name',
#  'where',
#  "'re",
#  'down',
#  'sometimes',
#  'she',
#  'which',
#  'until',
#  'another',
#  'will',
#  'into',
#  'throughout',
#  'using',
#  "'ve",
#  'amount',
#  'however',
#  'still',
#  'has',
#  'yours',
#  'he',
#  'others',
#  'them',
#  'itself',
#  'put',
#  'so',
#  'five',
#  'more',
#  'take',
#  'least',
#  'when',
#  'every',
#  '‘ve',
#  'is',
#  'if',
#  'whenever',
#  'various',
#  'without',
#  'as',
#  'seems',
#  'are',
#  'below',
#  'nor',
#  'against',
#  'himself',
#  'twenty',
#  'regarding',
#  'and',
#  '‘m',
#  're',
#  'herein',
#  'besides',
#  'anyone',
#  'across',
#  'afterwards',
#  'other',
#  'should',
#  'becoming',
#  'whereby',
#  'via',
#  'here',
#  'onto',
#  'being',
#  'fifteen',
#  'between',
#  'do',
#  'full',
#  'anything',
#  'therein',
#  'once',
#  'per',
#  'while',
#  'around',
#  'his',
#  'six',
#  'herself',
#  'over',
#  'give',
#  'twelve',
#  'already',
#  'by',
#  'keep',
#  '’re',
#  'whose',
#  'though',
#  'for',
#  'beside',
#  'its',
#  'have',
#  'see',
#  '’s',
#  'again',
#  'make',
#  "'d",
#  'last',
#  'beforehand',
#  'thereupon',
#  'n’t',
#  'former',
#  '‘re',
#  'hereby',
#  'whence',
#  'that',
#  'with',
#  'can',
#  'off',
#  'most',
#  'ca',
#  'always',
#  'indeed',
#  'wherein',
#  '’ve',
#  'wherever',
#  'although',
#  'meanwhile',
#  "'ll",
#  'my',
#  '‘ll',
#  'four',
#  'whom',
#  'anyway',
#  'beyond',
#  'a',
#  'what',
#  'during',
#  'well',
#  'alone',
#  'along',
#  'could',
#  'somewhere',
#  'anyhow',
#  'made',
#  'three',
#  'toward',
#  'unless',
#  '‘s',
#  'some',
#  '’d',
#  'either',
#  'third',
#  'us',
#  'fifty',
#  'were',
#  'latter',
#  'it',
#  'been',
#  'to',
#  'whereupon',
#  'everything',
#  'else',
#  'first',
#  'due',
#  'everywhere',
#  'before',
#  'less',
#  'after',
#  'formerly',
#  'top',
#  'everyone',
#  'few',
#  'all',
#  'call',
#  'behind',
#  'then',
#  'next',
#  "n't",
#  'up',
#  'serious',
#  'nowhere',
#  'their',
#  'somehow',
#  'themselves',
#  'front',
#  'might',
#  'enough',
#  'moreover',
#  'such',
#  'through',
#  'only',
#  'get',
#  'him',
#  'than',
#  'together',
#  'among',
#  'anywhere',
#  'hers',
#  'an',
#  'each',
#  '‘d',
#  'thereafter',
#  "'m",
#  'empty',
#  'may',
#  'something',
#  'these',
#  'neither',
#  'now',
#  'or',
#  'yet',
#  'same',
#  'seemed',
#  'any',
#  'further',
#  'doing',
#  'namely',
#  'mine',
#  'since',
#  'rather',
#  'never',
#  'on',
#  'nothing',
#  'thence',
#  'both',
#  'even',
#  'perhaps',
#  'amongst',
#  '’ll',
#  'latterly',
#  'yourself',
#  'her',
#  'am',
#  'therefore',
#  'move',
#  'one',
#  'would',
#  'nevertheless',
#  'someone',
#  'show',
#  'whereas',
#  'eleven',
#  'ever',
#  'you',
#  'did',
#  'at',
#  'ourselves',
#  'quite',
#  'must',
#  'sixty',
#  'of',
#  'whereafter',
#  'say',
#  'often',
#  'sometime',
#  'who',
#  'almost',
#  'but',
#  'hence',
#  'thru',
#  'about',
#  'mostly',
#  'from',
#  'became',
#  'back',
#  'thus',
#  'bottom',
#  'whole',
#  'why',
#  'whether',
#  'because',
#  'eight',
#  'your',
#  'too',
#  'i',
#  'please',
#  'they',
#  'our',
#  'very',
#  'seem',
#  'whoever',
#  '’m',
#  'in',
#  'there',
#  'be']

# %%
text ="""
"Boulder feels like a bubble and the bubble burst and that's heartbreaking. To think that people died today," Borowski said. Police have not confirmed whether anyone was killed.
"I didn't see the shooter. I saw terrified faces running towards me and that's when I turned and ran the other direction," he said.
"I got the call from my daughter and my grandchildren that my son-in-law walked into the pharmacy for him to get a Covid-19 shot and the shooter came in, shot the woman in front of them," the man told KCNC.
"Number one is clear the scene, make sure you eliminate whatever threat may be there and that that building is totally secure," Ramsey added.
"Right now, you've got to ensure this is the only person – if they picked up something already – and that the facility is secure," he told CNN on Monday as law enforcement are responding to the situation.
"They may give some preliminary information, but it won't be much. It will be pretty sketchy at this point in time. These scenes are very chaotic in the early stages. So it's got to settle down," he said.
"They were texting, hiding in the coat closet. Turned their phone off and were going ‘we’re hiding, we’re okay’ you know, ‘don't call’ you know the phone would ring and give away their position," he said.
"This feels like the safest spot in America and I just nearly got killed for getting a soda, you know, and a bag of chips. Doesn't feel good," he added.
"We told employees what was going on so everybody helped each other and we just ran to safety as quickly as we could," Borowski told CNN from behind the store in Boulder, Colorado, about two hours after the shooting.
An eyewitness told CNN affiliate KCNC he was inside the King Sooper grocery store at the time of the shooting. 
Borowski said he was going to get ice cream, but then changed his mind and started walking the other way.
Boulder Community Health is a Level II Trauma Center.
Boulder Community Health says they have had one patient transported to their facility from the shooting at King Soopers, Rich Sheehan, a spokesperson with Boulder Community Health, told CNN. 
Boulder police are urging people to stay inside because the scene at King Soopers is still "very active" as they respond to reports of an active shooter.
Boulder police say the scene is still "very active," but we do not know a lot of information about what happened – including the conditions of people inside the store.

            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
# Maximum Word Frequency
maximum_frequency = max(word_frequencies.values())

# %%
for word in word_frequencies.keys():  
        word_frequencies[word] = (word_frequencies[word]/maximum_frequency)

# %%
# Frequency Table
word_frequencies

sorted(word_frequencies.items(), key=lambda x: x[1])
# Out:
# [('burst', 0.014084507042253521),
#  ('heartbreaking', 0.014084507042253521),
#  ('To', 0.014084507042253521),
#  ('think', 0.014084507042253521),
#  ('died', 0.014084507042253521),
#  ('today', 0.014084507042253521),
#  ('confirmed', 0.014084507042253521),
#  ('saw', 0.014084507042253521),
#  ('terrified', 0.014084507042253521),
#  ('faces', 0.014084507042253521),
#  ('turned', 0.014084507042253521),
#  ('direction', 0.014084507042253521),
#  ('grandchildren', 0.014084507042253521),
#  ('son', 0.014084507042253521),
#  ('walked', 0.014084507042253521),
#  ('came', 0.014084507042253521),
#  ('woman', 0.014084507042253521),
#  ('Number', 0.014084507042253521),
#  ('clear', 0.014084507042253521),
#  ('eliminate', 0.014084507042253521),
#  ('threat', 0.014084507042253521),
#  ('totally', 0.014084507042253521),
#  ('Right', 0.014084507042253521),
#  ('ensure', 0.014084507042253521),
#  ('picked', 0.014084507042253521),
#  ('enforcement', 0.014084507042253521),
#  ('responding', 0.014084507042253521),
#  ('preliminary', 0.014084507042253521),
#  ('wo', 0.014084507042253521),
#  ('It', 0.014084507042253521),
#  ('pretty', 0.014084507042253521),
#  ('sketchy', 0.014084507042253521),
#  ('These', 0.014084507042253521),
#  ('scenes', 0.014084507042253521),
#  ('chaotic', 0.014084507042253521),
#  ('early', 0.014084507042253521),
#  ('stages', 0.014084507042253521),
#  ('So', 0.014084507042253521),
#  ('settle', 0.014084507042253521),
#  ('coat', 0.014084507042253521),
#  ('Turned', 0.014084507042253521),
#  ('okay', 0.014084507042253521),
#  ('ring', 0.014084507042253521),
#  ('position', 0.014084507042253521),
#  ('safest', 0.014084507042253521),
#  ('spot', 0.014084507042253521),
#  ('America', 0.014084507042253521),
#  ('nearly', 0.014084507042253521),
#  ('getting', 0.014084507042253521),
#  ('bag', 0.014084507042253521),
#  ('Does', 0.014084507042253521),
#  ('feel', 0.014084507042253521),
#  ('good', 0.014084507042253521),
#  ('safety', 0.014084507042253521),
#  ('quickly', 0.014084507042253521),
#  ('hours', 0.014084507042253521),
#  ('An', 0.014084507042253521),
#  ('Sooper', 0.014084507042253521),
#  ('ice', 0.014084507042253521),
#  ('cream', 0.014084507042253521),
#  ('changed', 0.014084507042253521),
#  ('mind', 0.014084507042253521),
#  ('walking', 0.014084507042253521),
#  ('way', 0.014084507042253521),
#  ('Level', 0.014084507042253521),
#  ('II', 0.014084507042253521),
#  ('Trauma', 0.014084507042253521),
#  ('Center', 0.014084507042253521),
#  ('says', 0.014084507042253521),
#  ('patient', 0.014084507042253521),
#  ('transported', 0.014084507042253521),
#  ('Rich', 0.014084507042253521),
#  ('spokesperson', 0.014084507042253521),
#  ('urging', 0.014084507042253521),
#  ('stay', 0.014084507042253521),
#  ('respond', 0.014084507042253521),
#  ('reports', 0.014084507042253521),
#  ('lot', 0.014084507042253521),
#  ('heard', 0.07042253521126761),
#  (':', 0.07042253521126761),
#  ('I', 0.08450704225352113),
#  ('inside', 0.08450704225352113),
#  ('Soopers', 0.08450704225352113),
#  ('scene', 0.09859154929577464),
#  ('know', 0.09859154929577464),
#  ('King', 0.09859154929577464),
#  ('active', 0.09859154929577464),
#  ('told', 0.11267605633802817),
#  ('police', 0.11267605633802817),
#  ('people', 0.1267605633802817),
#  ('He', 0.1267605633802817),
#  ('shooter', 0.15492957746478872),
#  ('Boulder', 0.18309859154929578),
#  ('CNN', 0.18309859154929578),
#  ('store', 0.2112676056338028),
#  ('said', 0.2535211267605634),
#  ('"', 0.4225352112676056),
#  ('\n', 0.7183098591549296),
#  ('.', 0.8169014084507042),
#  (',', 1.0)]

# %%
# Sentence Tokens
sentence_list = [ sentence for sentence in docx.sents ]

# %%
# Example of Sentence Tokenization,Word Tokenization and Lowering All Text
# for t in sentence_list:
#     for w in t:
#         print(w.text.lower())
[w.text.lower() for t in sentence_list for w in t ]
# Out:
# ['\n',
#  '"',
#  'boulder',
#  'feels',
#  'like',
#  'a',
#  'bubble',
#  'and',
#  'the',
#  'bubble',
#  'burst',
#  'and',
#  'that',
#  "'s",
#  'heartbreaking',
#  '.',
#  'to',
#  'think',
#  'that',
#  'people',
#  'died',
#  'today',
#  ',',
#  '"',
#  'borowski',
#  'said',
#  '.',
#  'police',
#  'have',
#  'not',
#  'confirmed',
#  'whether',
#  'anyone',
#  'was',
#  'killed',
#  '.',
#  '\n',
#  '"',
#  'i',
#  'did',
#  "n't",
#  'see',
#  'the',
#  'shooter',
#  '.',
#  'i',
#  'saw',
#  'terrified',
#  'faces',
#  'running',
#  'towards',
#  'me',
#  'and',
#  'that',
#  "'s",
#  'when',
#  'i',
#  'turned',
#  'and',
#  'ran',
#  'the',
#  'other',
#  'direction',
#  ',',
#  '"',
#  'he',
#  'said',
#  '.',
#  '\n',
#  '"',
#  'i',
#  'got',
#  'the',
#  'call',
#  'from',
#  'my',
#  'daughter',
#  'and',
#  'my',
#  'grandchildren',
#  'that',
#  'my',
#  'son',
#  '-',
#  'in',
#  '-',
#  'law',
#  'walked',
#  'into',
#  'the',
#  'pharmacy',
#  'for',
#  'him',
#  'to',
#  'get',
#  'a',
#  'covid-19',
#  'shot',
#  'and',
#  'the',
#  'shooter',
#  'came',
#  'in',
#  ',',
#  'shot',
#  'the',
#  'woman',
#  'in',
#  'front',
#  'of',
#  'them',
#  ',',
#  '"',
#  'the',
#  'man',
#  'told',
#  'kcnc',
#  '.',
#  '\n',
#  '"',
#  'number',
#  'one',
#  'is',
#  'clear',
#  'the',
#  'scene',
#  ',',
#  'make',
#  'sure',
#  'you',
#  'eliminate',
#  'whatever',
#  'threat',
#  'may',
#  'be',
#  'there',
#  'and',
#  'that',
#  'that',
#  'building',
#  'is',
#  'totally',
#  'secure',
#  ',',
#  '"',
#  'ramsey',
#  'added',
#  '.',
#  '\n',
#  '"',
#  'right',
#  'now',
#  ',',
#  'you',
#  "'ve",
#  'got',
#  'to',
#  'ensure',
#  'this',
#  'is',
#  'the',
#  'only',
#  'person',
#  '–',
#  'if',
#  'they',
#  'picked',
#  'up',
#  'something',
#  'already',
#  '–',
#  'and',
#  'that',
#  'the',
#  'facility',
#  'is',
#  'secure',
#  ',',
#  '"',
#  'he',
#  'told',
#  'cnn',
#  'on',
#  'monday',
#  'as',
#  'law',
#  'enforcement',
#  'are',
#  'responding',
#  'to',
#  'the',
#  'situation',
#  '.',
#  '\n',
#  '"',
#  'they',
#  'may',
#  'give',
#  'some',
#  'preliminary',
#  'information',
#  ',',
#  'but',
#  'it',
#  'wo',
#  "n't",
#  'be',
#  'much',
#  '.',
#  'it',
#  'will',
#  'be',
#  'pretty',
#  'sketchy',
#  'at',
#  'this',
#  'point',
#  'in',
#  'time',
#  '.',
#  'these',
#  'scenes',
#  'are',
#  'very',
#  'chaotic',
#  'in',
#  'the',
#  'early',
#  'stages',
#  '.',
#  'so',
#  'it',
#  "'s",
#  'got',
#  'to',
#  'settle',
#  'down',
#  ',',
#  '"',
#  'he',
#  'said',
#  '.',
#  '\n',
#  '"',
#  'they',
#  'were',
#  'texting',
#  ',',
#  'hiding',
#  'in',
#  'the',
#  'coat',
#  'closet',
#  '.',
#  'turned',
#  'their',
#  'phone',
#  'off',
#  'and',
#  'were',
#  'going',
#  '‘',
#  'we',
#  '’re',
#  'hiding',
#  ',',
#  'we',
#  '’re',
#  'okay',
#  '’',
#  'you',
#  'know',
#  ',',
#  '‘',
#  'do',
#  "n't",
#  'call',
#  '’',
#  'you',
#  'know',
#  'the',
#  'phone',
#  'would',
#  'ring',
#  'and',
#  'give',
#  'away',
#  'their',
#  'position',
#  ',',
#  '"',
#  'he',
#  'said',
#  '.',
#  '\n',
#  '"',
#  'this',
#  'feels',
#  'like',
#  'the',
#  'safest',
#  'spot',
#  'in',
#  'america',
#  'and',
#  'i',
#  'just',
#  'nearly',
#  'got',
#  'killed',
#  'for',
#  'getting',
#  'a',
#  'soda',
#  ',',
#  'you',
#  'know',
#  ',',
#  'and',
#  'a',
#  'bag',
#  'of',
#  'chips',
#  '.',
#  'does',
#  "n't",
#  'feel',
#  'good',
#  ',',
#  '"',
#  'he',
#  'added',
#  '.',
#  '\n',
#  '"',
#  'we',
#  'told',
#  'employees',
#  'what',
#  'was',
#  'going',
#  'on',
#  'so',
#  'everybody',
#  'helped',
#  'each',
#  'other',
#  'and',
#  'we',
#  'just',
#  'ran',
#  'to',
#  'safety',
#  'as',
#  'quickly',
#  'as',
#  'we',
#  'could',
#  ',',
#  '"',
#  'borowski',
#  'told',
#  'cnn',
#  'from',
#  'behind',
#  'the',
#  'store',
#  'in',
#  'boulder',
#  ',',
#  'colorado',
#  ',',
#  'about',
#  'two',
#  'hours',
#  'after',
#  'the',
#  'shooting',
#  '.',
#  '\n',
#  'an',
#  'eyewitness',
#  'told',
#  'cnn',
#  'affiliate',
#  'kcnc',
#  'he',
#  'was',
#  'inside',
#  'the',
#  'king',
#  'sooper',
#  'grocery',
#  'store',
#  'at',
#  'the',
#  'time',
#  'of',
#  'the',
#  'shooting',
#  '.',
#  '\n',
#  'borowski',
#  'said',
#  'he',
#  'was',
#  'going',
#  'to',
#  'get',
#  'ice',
#  'cream',
#  ',',
#  'but',
#  'then',
#  'changed',
#  'his',
#  'mind',
#  'and',
#  'started',
#  'walking',
#  'the',
#  'other',
#  'way',
#  '.',
#  '\n',
#  'boulder',
#  'community',
#  'health',
#  'is',
#  'a',
#  'level',
#  'ii',
#  'trauma',
#  'center',
#  '.',
#  '\n',
#  'boulder',
#  'community',
#  'health',
#  'says',
#  'they',
#  'have',
#  'had',
#  'one',
#  'patient',
#  'transported',
#  'to',
#  'their',
#  'facility',
#  'from',
#  'the',
#  'shooting',
#  'at',
#  'king',
#  'soopers',
#  ',',
#  'rich',
#  'sheehan',
#  ',',
#  'a',
#  'spokesperson',
#  'with',
#  'boulder',
#  'community',
#  'health',
#  ',',
#  'told',
#  'cnn',
#  '.',
#  '\n',
#  'boulder',
#  'police',
#  'are',
#  'urging',
#  'people',
#  'to',
#  'stay',
#  'inside',
#  'because',
#  'the',
#  'scene',
#  'at',
#  'king',
#  'soopers',
#  'is',
#  'still',
#  '"',
#  'very',
#  'active',
#  '"',
#  'as',
#  'they',
#  'respond',
#  'to',
#  'reports',
#  'of',
#  'an',
#  'active',
#  'shooter',
#  '.',
#  '\n',
#  'boulder',
#  'police',
#  'say',
#  'the',
#  'scene',
#  'is',
#  'still',
#  '"',
#  'very',
#  'active',
#  ',',
#  '"',
#  'but',
#  'we',
#  'do',
#  'not',
#  'know',
#  'a',
#  'lot',
#  'of',
#  'information',
#  'about',
#  'what',
#  'happened',
#  '–',
#  'including',
#  'the',
#  'conditions',
#  'of',
#  'people',
#  'inside',
#  'the',
#  'store',
#  '.',
#  '\n',
#  'boulder',
#  ',',
#  'colorado',
#  ',',
#  'mayor',
#  'sam',
#  'weaver',
#  'thanked',
#  'police',
#  'officers',
#  'and',
#  'first',
#  'responders',
#  'at',
#  'the',
#  'scene',
#  'of',
#  'an',
#  'active',
#  'shooter',
#  ',',
#  'saying',
#  '"',
#  'words',
#  'can',
#  'do',
#  'no',
#  'justice',
#  'to',
#  'the',
#  'tragedy',
#  'that',
#  'has',
#  'unfolded',
#  'this',
#  'afternoon',
#  '.',
#  '"',
#  '\n',
#  'by',
#  'veronica',
#  'rocha',
#  ',',
#  'elise',
#  'hammond',
#  ',',
#  'joshua',
#  'berlinger',
#  'and',
#  'adam',
#  'renton',
#  ',',
#  'cnn',
#  '\n',
#  'cnn',
#  'affiliate',
#  'kcnc',
#  'reporter',
#  'conor',
#  'mccue',
#  'spoke',
#  'with',
#  'a',
#  'man',
#  'whose',
#  'family',
#  'was',
#  'inside',
#  'the',
#  'king',
#  'soopers',
#  'pharmacy',
#  'to',
#  'get',
#  'a',
#  'covid-19',
#  'vaccine',
#  'when',
#  'the',
#  'shooter',
#  'arrived',
#  '.',
#  'he',
#  'said',
#  'they',
#  'hid',
#  'in',
#  'a',
#  'closet',
#  'for',
#  'an',
#  'hour',
#  'before',
#  'being',
#  'rescued',
#  'through',
#  'the',
#  'roof',
#  '.',
#  '\n',
#  'cnn',
#  'affiliate',
#  'kmgh',
#  '’s',
#  'helicopter',
#  'also',
#  'filmed',
#  'several',
#  'people',
#  'led',
#  'away',
#  'from',
#  'the',
#  'king',
#  'soopers',
#  'store',
#  'by',
#  'police',
#  '.',
#  'swat',
#  'vehicles',
#  'were',
#  'also',
#  'seen',
#  'moving',
#  'about',
#  ',',
#  'and',
#  'multiple',
#  'officers',
#  'were',
#  'in',
#  'tactical',
#  'positions',
#  'around',
#  'the',
#  'store',
#  '’s',
#  'exterior',
#  '.',
#  '\n',
#  'cnn',
#  'affiliate',
#  'kmgh',
#  '’s',
#  'helicopter',
#  'recorded',
#  'a',
#  'shirtless',
#  'man',
#  'being',
#  'taken',
#  'from',
#  'the',
#  'supermarket',
#  '.',
#  'the',
#  'man',
#  'had',
#  'what',
#  'appears',
#  'to',
#  'be',
#  'blood',
#  'on',
#  'his',
#  'arm',
#  'and',
#  'right',
#  'leg',
#  'and',
#  'his',
#  'hands',
#  'appeared',
#  'to',
#  'be',
#  'cuffed',
#  'behind',
#  'him',
#  'as',
#  'two',
#  'officers',
#  'escorted',
#  'him',
#  'away',
#  '.',
#  'the',
#  'man',
#  'was',
#  'taken',
#  'away',
#  'in',
#  'an',
#  'ambulance',
#  '.',
#  '\n',
#  'cnn',
#  '’s',
#  'lucy',
#  'kafanov',
#  'reported',
#  'seeing',
#  'fbi',
#  'agents',
#  'on',
#  'the',
#  'scene',
#  'at',
#  'the',
#  'supermarket',
#  '.',
#  '\n',
#  'charles',
#  'ramsey',
#  ',',
#  'a',
#  'former',
#  'philadelphia',
#  'police',
#  'commissioner',
#  ',',
#  'said',
#  'officials',
#  'need',
#  'to',
#  'make',
#  'sure',
#  'the',
#  'building',
#  'is',
#  'secure',
#  'before',
#  'releasing',
#  'more',
#  'information',
#  '.',
#  '\n',
#  'colorado',
#  'gov.',
#  'jared',
#  'polis',
#  'said',
#  'earlier',
#  'that',
#  'he',
#  'is',
#  '"',
#  'closely',
#  'watching',
#  '"',
#  'as',
#  'events',
#  'unfold',
#  '.',
#  '\n',
#  'fbi',
#  'denver',
#  'personnel',
#  'are',
#  'on',
#  'scene',
#  'helping',
#  'the',
#  'boulder',
#  'police',
#  'department',
#  ',',
#  'according',
#  'to',
#  'a',
#  'tweet',
#  '.',
#  '\n',
#  'from',
#  'cnn',
#  "'s",
#  'jamiel',
#  'lynch',
#  '\n',
#  'from',
#  'cnn',
#  "'s",
#  'paul',
#  'murphy',
#  '\n',
#  'from',
#  'cnn',
#  '’s',
#  'jamiel',
#  'lynch',
#  '\n',
#  'from',
#  'cnn',
#  '’s',
#  'keith',
#  'allen',
#  '\n',
#  'he',
#  'described',
#  'an',
#  'urgent',
#  ',',
#  'but',
#  'orderly',
#  'escape',
#  'from',
#  'the',
#  'store',
#  '.',
#  '\n',
#  'he',
#  'said',
#  'everyone',
#  'was',
#  'helping',
#  'each',
#  'other',
#  ',',
#  'but',
#  'while',
#  'some',
#  'people',
#  'ran',
#  ',',
#  'others',
#  'froze',
#  '.',
#  '\n',
#  'he',
#  'said',
#  'he',
#  'could',
#  'have',
#  'never',
#  'imagined',
#  'a',
#  'situation',
#  'like',
#  'this',
#  'happening',
#  'in',
#  'boulder',
#  '.',
#  '\n',
#  'he',
#  'said',
#  'he',
#  'heard',
#  'two',
#  'loud',
#  'sounds',
#  ',',
#  'and',
#  'by',
#  'the',
#  'third',
#  'one',
#  ',',
#  'he',
#  'and',
#  'the',
#  'people',
#  'around',
#  'him',
#  'realized',
#  'they',
#  'were',
#  'gunshots',
#  '.',
#  'he',
#  'said',
#  'they',
#  'started',
#  'running',
#  'to',
#  'the',
#  'back',
#  'of',
#  'the',
#  'store',
#  'and',
#  'employees',
#  'helped',
#  'them',
#  'out',
#  'the',
#  'back',
#  'door',
#  '.',
#  '\n',
#  'he',
#  'said',
#  'his',
#  'daughter',
#  'was',
#  'texting',
#  'him',
#  'from',
#  'the',
#  'closet',
#  ',',
#  'before',
#  'turning',
#  'her',
#  'phone',
#  'off',
#  '.',
#  '\n',
#  'he',
#  'said',
#  'this',
#  'is',
#  'not',
#  'an',
#  'easy',
#  'task',
#  ',',
#  'and',
#  'it',
#  'will',
#  'take',
#  'time',
#  'to',
#  'make',
#  'sure',
#  'it',
#  'is',
#  'safe',
#  '.',
#  '\n',
#  'he',
#  'told',
#  'kcnc',
#  ':',
#  '"',
#  'we',
#  'were',
#  "n't",
#  'tripping',
#  'over',
#  'each',
#  'other',
#  ',',
#  'but',
#  'we',
#  'were',
#  'single',
#  'file',
#  'just',
#  'you',
#  'know',
#  ',',
#  'somebody',
#  'had',
#  'their',
#  'hand',
#  'on',
#  'my',
#  'back',
#  ',',
#  'i',
#  'had',
#  'my',
#  'hand',
#  ...]

# %%
# Sentence Score via comparrng each word with sentence
sentence_scores = {}  
for sent in sentence_list:  
        for word in sent:
            if word.text.lower() in word_frequencies.keys():
                if len(sent.text.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word.text.lower()]
                    else:
                        sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
# Sentence Score Table
sentence_scores
# Out:
# {
#  "Boulder feels like a bubble and the bubble burst: 1.2816901408450703,
#  and that's heartbreaking.: 0.8309859154929577,
#  To think that people died today," Borowski said.: 2.661971830985916,
#  Police have not confirmed whether anyone was killed.: 1.6901408450704225,
#  "I didn't see the shooter.: 1.3943661971830985,
#  I saw terrified faces running towards me and that's when I turned and ran the other direction," he said.: 3.3661971830985915,
#  "Number one is clear the scene, make sure you eliminate whatever threat may be there and that that building is totally secure," Ramsey added.: 4.71830985915493,
#  "They may give some preliminary information, but it won't be much.: 2.323943661971831,
#  It will be pretty sketchy at this point in time.: 0.9295774647887324,
#  These scenes are very chaotic in the early stages.: 0.8732394366197184,
#  So it's got to settle down," he said.: 3.2816901408450705,
#  "They were texting, hiding in the coat closet.: 2.352112676056338,
#  Turned their phone off and were going ‘we’re hiding, we’re okay’ you know, ‘don't call’: 2.352112676056338,
#  you know the phone would ring and give away their position," he said.: 3.4366197183098595,
#  "This feels like the safest spot in America: 0.5211267605633803,
#  and I just nearly got killed for getting a soda, you know, and a bag of chips.: 3.098591549295775,
#  Doesn't feel good," he added.: 3.0140845070422535,
#  "We told employees what was going on: 0.6056338028169013,
#  An eyewitness told CNN affiliate KCNC: 0.1971830985915493,
#  he was inside the King Sooper grocery store at the time of the shooting. : 1.9859154929577465,
#  Borowski said he was going to get ice cream, but then changed his mind and started walking the other way.: 2.9436619718309855,
#  Boulder Community Health is a Level II Trauma Center.: 1.535211267605634,
#  Boulder police are urging people to stay inside because the scene at King Soopers is still "very active" as they respond to reports of an active shooter.: 3.2112676056338025,
#  By Veronica Rocha, Elise Hammond, Joshua Berlinger and Adam Renton, CNN: 3.7183098591549295,
#  CNN affiliate KCNC reporter Conor McCue spoke with a man whose family was inside the King Soopers pharmacy to get a Covid-19 vaccine when the shooter arrived.: 1.295774647887324,
#  He said they hid in a closet for an hour before being rescued through the roof.: 1.915492957746479,
#  CNN affiliate KMGH’s helicopter also filmed several people led away from the King Soopers store by police.: 1.436619718309859,
#  SWAT vehicles were also seen moving about, and multiple officers were in tactical positions around the store’s exterior.: 2.929577464788732,
#  CNN affiliate KMGH’s helicopter recorded a shirtless man being taken from the supermarket.: 1.0985915492957745,
#  The man had what appears to be blood on his arm and right leg and his hands appeared to be cuffed behind him as two officers escorted him away.: 1.1408450704225352,
#  The man was taken away in an ambulance.: 1.732394366197183,
#  Lucy Kafanov reported seeing FBI agents on the scene at the supermarket.: 1.7183098591549295,
#  Charles Ramsey, a former Philadelphia police commissioner, said officials need to make sure the building is secure before releasing more information.: 4.183098591549296,
#  Colorado Gov. Jared Polis said earlier that he is "closely watching" as events unfold.: 2.7183098591549295,
#  FBI Denver personnel are on scene helping the Boulder Police Department, according to a tweet.: 2.8169014084507045,
#  From CNN's Jamiel Lynch
#  From CNN's Paul Murphy
#  From CNN’s Jamiel Lynch: 2.154929577464789,
#  From CNN’s Keith Allen: 0.7183098591549296,
#  He described an urgent, but orderly escape from the store. : 2.8028169014084505,
#  He said everyone was helping each other, but while some people ran, others froze.: 4.000000000000001,
#  He said he could have never imagined a situation like this happening in Boulder.: 1.887323943661972,
#  He said he heard two loud sounds, and by the third one, he and the people around him realized they were gunshots.: 3.352112676056338,
#  He said they started running to the back of the store and employees helped them out the back door.: 2.1549295774647885,
#  He said his daughter was texting him from the closet, before turning her phone off.: 2.9436619718309855,
#  He said this is not an easy task, and it will take time to make sure it is safe.: 2.9436619718309855,
#  He told KCNC: "We weren't tripping over each other, but we were single file just you know,: 2.746478873239437,
#  somebody had their hand on my back, I had my hand on somebody's back, and we were just saying go, go, go, run.": 7.15492957746479,
#  Here's how that conversation played out:: 0.8169014084507042,
#  In the excerpt, Schiller is heard calling out saying that people need to call 9-1-1. : 3.014084507042253,
#  Police were also seen moving on the roof of the store, the purposes for the roof movements are unclear.: 3.0422535211267605,
#  Schiller is heard on the video asking what appears to be a store employee whether a shooter went into the store.: 2.3380281690140845,
#  Sheehan said he is not able to release details about the person’s condition. : 1.8732394366197185,
#  Some background:: 0.08450704225352113,
#  Boulder Police had tweeted earlier on Monday there was an, “Active Shooter at the King Soopers on Table Mesa.: 2.295774647887324,
#  AVOID THE AREA.”: 1.619718309859155,
#  The video, taken by Dean Schiller, is part of a longer live stream that he took as the shooting progressed and police arrived. : 3.9154929577464785,
#  Video taken by an eyewitness to the Boulder, Colorado, supermarket shooting appears to show people lying on the ground inside and outside the store, and purported gunshots are heard.: 5.394366197183099,
#  Watch here:: 0.7887323943661972,
#  We don't know about the conditions of anyone else in the store at this time.: 1.9295774647887325,
#  “Please avoid the area of Table Mesa & Broadway!: 0.11267605633802816,
#  This is still a very active scene,” Boulder police tweeted moments ago.: 2.23943661971831,
#  “Do NOT broadcast on social media any tactical information you might see.”: 1.7746478873239435,
#  “We don’t know if there’s a shooter — active shooter, active shooter somewhere,” Schiller said in the video. : 4.71830985915493}

# %%
# Import Heapq 
from heapq import nlargest

# %%
summarized_sentences = nlargest(6, sentence_scores, key=sentence_scores.get)

# %%
summarized_sentences
# Out:
# [somebody had their hand on my back, I had my hand on somebody's back, and we were just saying go, go, go, run.",
#  Video taken by an eyewitness to the Boulder, Colorado, supermarket shooting appears to show people lying on the ground inside and outside the store, and purported gunshots are heard.,
#  "Number one is clear the scene, make sure you eliminate whatever threat may be there and that that building is totally secure," Ramsey added.,
#  “We don’t know if there’s a shooter — active shooter, active shooter somewhere,” Schiller said in the video. ,
#  Charles Ramsey, a former Philadelphia police commissioner, said officials need to make sure the building is secure before releasing more information.,
#  He said everyone was helping each other, but while some people ran, others froze.]

# %%
# Convert Sentences from Spacy Span to Strings for joining entire sentence
for w in summarized_sentences:
    print(w.text)
# Out:
# somebody had their hand on my back, I had my hand on somebody's back, and we were just saying go, go, go, run."
#
# Video taken by an eyewitness to the Boulder, Colorado, supermarket shooting appears to show people lying on the ground inside and outside the store, and purported gunshots are heard.
#
# "Number one is clear the scene, make sure you eliminate whatever threat may be there and that that building is totally secure," Ramsey added.
#
# “We don’t know if there’s a shooter — active shooter, active shooter somewhere,” Schiller said in the video.
#
# Charles Ramsey, a former Philadelphia police commissioner, said officials need to make sure the building is secure before releasing more information.
#
# He said everyone was helping each other, but while some people ran, others froze.

# %%
# List Comprehension of Sentences Converted From Spacy.span to strings
final_sentences = [ w.text for w in summarized_sentences ]

# %%
summary = ' '.join(final_sentences)

# %%
summary
# Out:
# '"In a building of that size, that\xa0you can clear the building and\xa0guarantee that nobody else is in\xa0there, think about every storage\xa0component in that building,\xa0every refrigerated room.\xa0 "In a building of that size, that\xa0you can clear the building and\xa0guarantee that nobody else is in\xa0there, think about every storage\xa0component in that building,\xa0every refrigerated room.\xa0 "In a building of that size, that\xa0you can clear the building and\xa0guarantee that nobody else is in\xa0there, think about every storage\xa0component in that building,\xa0every refrigerated room.\xa0 "In a building of that size, that\xa0you can clear the building and\xa0guarantee that nobody else is in\xa0there, think about every storage\xa0component in that building,\xa0every refrigerated room.\xa0 "In a building of that size, that\xa0you can clear the building and\xa0guarantee that nobody else is in\xa0there, think about every storage\xa0component in that building,\xa0every refrigerated room.\xa0'
